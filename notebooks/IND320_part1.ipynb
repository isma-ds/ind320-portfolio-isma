# %% [markdown]
# # IND320 – Part 1 Notebook
# **Author:** Isma Sohail
# **Course:** IND320
#
# Use the headings to keep this notebook navigable and exportable to PDF (all cells executed).

# %% [markdown]
# ## About This Project
# This IND320 portfolio integrates a Jupyter Notebook and Streamlit app to demonstrate reading, analyzing, and visualizing time-series data.

# %% [markdown]
# ## AI Usage
# Briefly describe how AI tools assisted and what you validated yourself.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
csv_path = Path('../data/open-meteo-subset.csv')  # Adjust path if needed
df = pd.read_csv(csv_path)
df.head()

# %% [markdown]
# ## Quick Summary & Preview

# %%
print('Shape:', df.shape)
print('\nColumns:', list(df.columns))
display(df.describe(include='all'))

# %% [markdown]
# ## Plot Each Column Separately

# %%
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        plt.figure()
        plt.plot(df[col])
        plt.title(col)
        plt.xlabel('Index')
        plt.ylabel('Value')
        plt.show()
    else:
        print(f'Skipping non-numeric column: {col}')

# %% [markdown]
# ## Plot All Columns Together

# %%
plt.figure()
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        plt.plot(df[col], label=col)
plt.title('All Numeric Columns')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ## Log (300–500 words)
# Describe your compulsory work here (Jupyter + Streamlit).

# %% [markdown]
# ## Links
# - GitHub repo: (add after pushing)
# - Streamlit app: (add after deployment)
